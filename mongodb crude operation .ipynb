# %%
pip install pymongo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for pymongo from https://files.pythonhosted.org/packages/c8/1a/1ba5578cc3acc8ef0dfd6eb9385f9c4b0fe3039665af93bcf062c34fcdb6/pymongo-4.6.1-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for dnspython<3.0.0,>=1.16.0 from https://files.pythonhosted.org/packages/b6/83/4a684a63d395007670bc95c1947c07045fe66141574e2f7e9e347df8499a/dnspython-2.5.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/472.7 kB ? eta -:--:--
#    ---- ---------------------------------- 51.2/472.7 kB 871.5 kB/s eta 0:00:01
#    ------------------- -------------------- 235.5/472.7 kB 2.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 409.6/472.7 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  471.0/472.7 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 472.7/472.7 kB 2.1 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

# %%
pip install pymongo
import pymongo

class MOngoDatabase:
    def __init__(self):
        self.cli = pymongo.MongoClient("localhost", 27017)
        print("You are connected to the local MongoDB database")
        
    def showDb(self):
        c = self.cli.list_database_names()
        for i in c:
            print(i)
            
    def selectDatabase(self, Name):
        databaseList = self.cli.list_database_names()
        if Name in databaseList:
            self.db = self.cli[Name]
            print("Now you are in {} ".format(Name))
        else:
            self.db = self.cli[Name]
        return self.db
    
    def createUseCol(self, ColName):
        if hasattr(self, 'db'):
            collection = self.db[ColName]
            print("Using/creating collection '{}' in the '{}' database.".format(ColName, self.db.name))
            return collection
        else:
            print("Please select a database first.")
    
    def insertOneData(self, collection, data):
        if collection is not None:
            result = collection.insert_one(data)
            print("Inserted data with id:", result.inserted_id)
        else:
            print("Please create or use collection first.")
    def insertManyData(self,collection,data):
        if collection is not None:
            result=collection.insert_many(data)
            print("Inserted data with ids:", result.inserted_ids)
        else:
            print("please create or use a collection frist")
            
    def findOne(self,collection,data):
        if collection is not None:
            result=collection.find_one(data)
            if result is not None:
                return result
            else:
                print("no document found maching the query")
        else:
            print("please create or use a collection frist")
    def findAll(self,collection,data):
        if collection is not None:
            result=collection.find(data)
            if result is not None:
                for res in result :
                    print(res)
                    
            else:
                print("no document found maching the query")
        else:
            print("please create or use a collection frist")
    def delOne(self,collection,data):
        if collection is not None:
            result=collection.delete_one(data)
            print("data deleted")
        else:
            print("please select a collection frist")
    def delMany(self,collection,data):
        if collection is not None:
            result=collection.delete_many(data)
            print("all maching data deleted")
        else:
            print("please select a collection frist")
            
    def updateOne(self ,collection,data):
        if collection is not None:
            result=collection.update_many()
            print ("qry is updated")
        else:
            print("please select the ")
            
    def many(self ,collection,data):
        if collection is not None:
            result=collection.update_many()
            print ("qry is updated")
        else:
            print("please select the ")
    

# Create an instance of MOngoDatabase
l = MOngoDatabase()

# View databases
l.showDb()

# Select a database
l.selectDatabase("roshan")

# Create or use a collection
collection = l.createUseCol("rosha")

# Insert one data into the collection
#data = {"Name": "roshan", "RollNo": 55}
#l.insertOneData(collection, data)
#insert many data into a collection 
"""data=[{"key1":"val1"},{"key2":"val2"},
      {"key3":"val3"},{"key4":"val4"},
      {"key5":"val5"},{"key6":"val6"}]
"""
#l.insertManyData(collection,data)
#finde a value
data={"key1":"val1"}
data2 = [
  { "_id": 1, "name": "John", "address": "Highway 37"},
  { "_id": 2, "name": "Peter", "address": "Lowstreet 27"},
  { "_id": 3, "name": "Amy", "address": "Apple st 652"},
  { "_id": 4, "name": "Hannah", "address": "Mountain 21"},
  { "_id": 5, "name": "Michael", "address": "Valley 345"},
  { "_id": 6, "name": "Sandy", "address": "Ocean blvd 2"},
  { "_id": 7, "name": "Betty", "address": "Green Grass 1"},
  { "_id": 8, "name": "Richard", "address": "Sky st 331"},
  { "_id": 9, "name": "Susan", "address": "One way 98"},
  { "_id": 10, "name": "Vicky", "address": "Yellow Garden 2"},
  { "_id": 11, "name": "Ben", "address": "Park Lane 38"},
  { "_id": 12, "name": "William", "address": "Central st 954"},
  { "_id": 13, "name": "Chuck", "address": "Main Road 989"},
  { "_id": 14, "name": "Viola", "address": "Sideway 1633"}
]
l.insertManyData(collection,data2)
#finding one data
l.findeOne(collection,data)
#finding all data
l.findall(collection,data)
#deleting one data from mongo db
l.delOne(collection,data)
#deleting many data from mongo db
l.delMany(collection,data)
# Out:
# You are connected to the local MongoDB database
# Test1
# admin
# config
# local
# rahul1
# roshan
# test
# test3
# Now you are in roshan
# Using/creating collection 'rosha' in the 'roshan' database.
